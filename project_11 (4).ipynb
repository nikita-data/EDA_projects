# %% [markdown]
# # Исследование рынка заведений общественного питания Москвы

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных</a></span><ul class="toc-item"><li><span><a href="#Считаем-CSV-файл-и-GeoJSON-файл--с-данными" data-toc-modified-id="Считаем-CSV-файл-и-GeoJSON-файл--с-данными-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Считаем CSV-файл и GeoJSON-файл  с данными</a></span></li><li><span><a href="#Выведем-первые-строки--набора-данных-и-изучим-общую-информацию-датафрейма" data-toc-modified-id="Выведем-первые-строки--набора-данных-и-изучим-общую-информацию-датафрейма-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Выведем первые строки  набора данных и изучим общую информацию датафрейма</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Обработка-явных--дубликатов" data-toc-modified-id="Обработка-явных--дубликатов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработка явных  дубликатов</a></span></li><li><span><a href="#Обработка-неявных--дубликатов" data-toc-modified-id="Обработка-неявных--дубликатов-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обработка неявных  дубликатов</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Обработка-аномальных-значений" data-toc-modified-id="Обработка-аномальных-значений-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Обработка аномальных значений</a></span></li><li><span><a href="#Добавление-столбцов" data-toc-modified-id="Добавление-столбцов-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Добавление столбцов</a></span><ul class="toc-item"><li><span><a href="#Добавление-столбца-street" data-toc-modified-id="Добавление-столбца-street-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>Добавление столбца street</a></span></li><li><span><a href="#Добавление-столбца-is_24/7" data-toc-modified-id="Добавление-столбца-is_24/7-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>Добавление столбца is_24/7</a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных-рынка-общепита" data-toc-modified-id="Исследовательский-анализ-данных-рынка-общепита-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных рынка общепита</a></span><ul class="toc-item"><li><span><a href="#Распределение-заведений-по-категориям" data-toc-modified-id="Распределение-заведений-по-категориям-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Распределение заведений по категориям</a></span></li><li><span><a href="#Распределение-посадочных-мест-по-категориям-заведений" data-toc-modified-id="Распределение-посадочных-мест-по-категориям-заведений-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Распределение посадочных мест по категориям заведений</a></span></li><li><span><a href="#Cоотношение-сетевых-и-несетевых-заведений" data-toc-modified-id="Cоотношение-сетевых-и-несетевых-заведений-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Cоотношение сетевых и несетевых заведений</a></span></li><li><span><a href="#Распределение-сетевых-заведений-по-категориям" data-toc-modified-id="Распределение-сетевых-заведений-по-категориям-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Распределение сетевых заведений по категориям</a></span></li><li><span><a href="#Топ-15-популярных-сетей-в-Москве" data-toc-modified-id="Топ-15-популярных-сетей-в-Москве-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Топ-15 популярных сетей в Москве</a></span></li><li><span><a href="#Распределение--заведений-по-категориям-в-разрезе-административных-районов" data-toc-modified-id="Распределение--заведений-по-категориям-в-разрезе-административных-районов-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Распределение  заведений по категориям в разрезе административных районов</a></span></li><li><span><a href="#Распределение--рейтингов-по-категориям-заведений" data-toc-modified-id="Распределение--рейтингов-по-категориям-заведений-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Распределение  рейтингов по категориям заведений</a></span></li><li><span><a href="#Фоновая-картограмма--со-средним-рейтингом-заведений-каждого-района" data-toc-modified-id="Фоновая-картограмма--со-средним-рейтингом-заведений-каждого-района-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Фоновая картограмма  со средним рейтингом заведений каждого района</a></span></li><li><span><a href="#Распределение-заведений-на-карте" data-toc-modified-id="Распределение-заведений-на-карте-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Распределение заведений на карте</a></span></li><li><span><a href="#Распределение--заведений-по-категориям-в-разрезе-городских-улиц" data-toc-modified-id="Распределение--заведений-по-категориям-в-разрезе-городских-улиц-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Распределение  заведений по категориям в разрезе городских улиц</a></span></li><li><span><a href="#Городские-улицы-с-одним-объектом-общепита" data-toc-modified-id="Городские-улицы-с-одним-объектом-общепита-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Городские улицы с одним объектом общепита</a></span></li><li><span><a href="#Распределение-медианного-значения-средних-чеков-заведений-по-округам" data-toc-modified-id="Распределение-медианного-значения-средних-чеков-заведений-по-округам-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Распределение медианного значения средних чеков заведений по округам</a></span></li></ul></li><li><span><a href="#Исследование-рынка-кофеен" data-toc-modified-id="Исследование-рынка-кофеен-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследование рынка кофеен</a></span><ul class="toc-item"><li><span><a href="#Распределение-кофеен-по-округам" data-toc-modified-id="Распределение-кофеен-по-округам-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Распределение кофеен по округам</a></span></li><li><span><a href="#Распределение-круглосуточных-кофеен" data-toc-modified-id="Распределение-круглосуточных-кофеен-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Распределение круглосуточных кофеен</a></span></li><li><span><a href="#Распределение-рейтингов-кофеен--по-административным-округам" data-toc-modified-id="Распределение-рейтингов-кофеен--по-административным-округам-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Распределение рейтингов кофеен  по административным округам</a></span></li><li><span><a href="#Распределение-стоимости-чашки-капучино-в-кофейнях" data-toc-modified-id="Распределение-стоимости-чашки-капучино-в-кофейнях-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Распределение стоимости чашки капучино в кофейнях</a></span></li><li><span><a href="#Рекомендации-для-открытия-новой-кофейни" data-toc-modified-id="Рекомендации-для-открытия-новой-кофейни-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Рекомендации для открытия новой кофейни</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Презентация-исследования" data-toc-modified-id="Презентация-исследования-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Презентация исследования</a></span></li></ul></div>

# %% [markdown]
# **Описание проекта**

# %% [markdown]
# В рамках данного проекта мы подготовим исследование рынка Москвы для открытия заведения общественного питания. Найдём интересные особенности и презентуем полученные результаты, которые в будущем помогут в выборе подходящего места для инвесторов из фонда «Shut Up and Take My Money»

# %% [markdown]
# **Предоставленные файлы**

# %% [markdown]
# - `moscow_places.csv` - датасет с заведениями общественного питания Москвы, составленный на основе данных сервисов Яндекс Карты и Яндекс Бизнес на лето 2022 года. Информация, размещённая в сервисе Яндекс Бизнес, могла быть добавлена пользователями или найдена в общедоступных источниках. Она носит исключительно справочный характер.
# - `admin_level_geomap.geojson` - текстовый файл в формате GeoJSON с информацией границ районов Москвы.Файл содержит границы областей в виде полигонов — многоугольников, которые задаются вершинами в виде широты и долготы.

# %% [markdown]
# **Цель исследования**

# %% [markdown]
# - Проанализировать полученные данные, найти зависимости и особенности заведений исходя из локации,категории и других параметров.
# - Собрать наблюдения в один общий вывод, для дальнейшего принятия решения в выборе подходящего заведения общественного питания.
# - Дать рекомендацию для открытия нового заведения.

# %% [markdown]
# **Основные шаги**

# %% [markdown]
# 1. Открытие файла с данными и изучение общей информации
# 2. Предобработка данных
# 3. Исследовательский анализ данных рынка общепита
# 4. Исследование рынка кофеен
# 5. Общий вывод
# 6. Презентация исследования

# %% [markdown]
# ## Обзор данных

# %%
# %%capture

#Установка менеджера пакетов pip для модуля missingno
# !pip install missingno

#Установка менеджера пакетов pip для модуля folium
# !pip install folium

# %%
# импорт библиотек
import pandas as pd
import matplotlib.pyplot as plt
import math 
import scipy.stats as st
import numpy as np
import random
import seaborn as sns
import warnings
import re
import missingno as msno
import plotly.express as px 
import datetime
import os

# подключаем модуль для работы с JSON-форматом
import json

#импорт модуля graph_objects
from plotly import graph_objects as go

#импорты классов и методов из библиотеки Folium
from folium import Map, Choropleth
from folium import Map, Marker
from folium.plugins import MarkerCluster

# %%
# устанавливка опции display.max_colwidth равной None, что означает, 
# что ширина столбцов при выводе данных в DataFrame не будет ограничена максимальной длиной.

pd.set_option('display.max_colwidth', None)

# %%
# убираем системные предупреждения

warnings.filterwarnings('ignore')

# %% [markdown]
# ###  Считаем CSV-файл и GeoJSON-файл  с данными

# %%
try:       
    data = pd.read_csv('D:\myuser\YandexPracticumfilesproject\moscow_places.csv')

except:    
    data = pd.read_csv('https://code.s3.yandex.net/datasets/moscow_places.csv')

# %%
# читаем GeoJSON-файл и сохраняем в переменной geo_json с использованием кодировки UTF-8
# файл содержит границы областей в виде полигонов — многоугольников, которые задаются вершинами в виде широты и долготы.

try:
    with open(r"D:\myuser\Yandex Practicum JSON file\admin_level_geomap.geojson", 'r', encoding='utf-8') as f:
        geo_json = json.load(f)
except FileNotFoundError:
    url = 'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'
    response = requests.get(url)
    if response.status_code == 200:
        geo_json = response.json()
    else:
        print("Ошибка при загрузке файла:", response.status_code)
except Exception as e:
    print("Произошла ошибка:", e)

# %% [markdown]
# ### Выведем первые строки  набора данных и изучим общую информацию датафрейма

# %%
# Выведем первые 10 строк таблицы

display(data.head(10))

# %% [markdown]
# В таблице 14 столбцов:
# - **name** — название заведения
# - **category** — категория заведения, например «кафе», «пиццерия» или «кофейня»
# - **address** — адрес заведения
# - **district** — административный район, в котором находится заведение, например Центральный административный округ
# - **hours** — информация о днях и часах работы
# - **lat** — широта географической точки, в которой находится заведение
# - **lng** — долгота географической точки, в которой находится заведение
# - **rating** — рейтинг заведения по оценкам пользователей в Яндекс Картах (высшая оценка — 5.0)
# - **price** — категория цен в заведении, например «средние», «ниже среднего», «выше среднего» и так далее
# - **avg_bill** — строка, которая хранит среднюю стоимость заказа в виде диапазона, например:
#   - «Средний счёт: 1000–1500 ₽»;
#   - «Цена чашки капучино: 130–220 ₽»;
#   - «Цена бокала пива: 400–600 ₽».
#
# - **middle_avg_bill** — число с оценкой среднего чека, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Средний счёт»:
#   - Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
#   - Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
#   - Если значения нет или оно не начинается с подстроки «Средний счёт», то в столбец ничего не войдёт.
# - **middle_coffee_cup** — число с оценкой одной чашки капучино, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Цена одной чашки капучино»:
#   - Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
#   - Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
#   - Если значения нет или оно не начинается с подстроки «Цена одной чашки капучино», то в столбец ничего не войдёт.
# - **chain** — число, выраженное 0 или 1, которое показывает, является ли заведение сетевым (для маленьких сетей могут встречаться ошибки):
#   - 0 — заведение не является сетевым
#   - 1 — заведение является сетевым
# - **seats** — количество посадочных мест.

# %%
# Посмотрим общую информацию о DataFrame

data.info()

# %% [markdown]
# В представленном для анализа файле - данные о заведениях общественного питания Москвы.Всего представлено 8406 заведений. Предварительно данных достаточно для анализа.
#
# По полученной информации и первичном анализе видно следующее:
# - В столбцах: (`hours, price, avg_bill, middle_avg_bill, middle_coffee_cup, seats`) имеются пропущенные значения. Придётся рассмотреть все столбцы и заполнить пропуски где это будет необходимо и возможно.
# - Необходимо добавление столбца c названиями улиц, а также отдельного столбца с  обозначением, что заведение работает ежедневно и круглосуточно (24/7).
# - В столбце `seats` неверный тип данных, в процессе предобработки изменим тип данных на формат целого числа int.
# - Наименование столбцов стилистически верное.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
#  В ходе обзора данных были обнаружены пропуски по  столбцам, определим их количество в столбцах.

# %%
data.isna().sum()

# %% [markdown]
# Для визуальной оценки пропусков выведем матрицу пропущенных значений (библиотека missingo).Визуализация пропусков показывает матрицу всех значений вида строка-столбец. И на пересечении черный цвет, если заполнено. И белый, если пропуск. Это позволяет сразу оценить пробелы в данных во всем наборе.

# %%
msno.matrix(data,labels=True);

# %% [markdown]
# Мы можем увидеть, что распределение пропусков по столбцам достаточно равномерное по всему датафрейму.По столбцам: `hours`,`price`,`avg_bill`,`middle_avg_bill`,`middle_coffee_cup`,`seats` заметна серьёзная нехватка значений.

# %% [markdown]
# Теперь посмотрим долю пропусков и на основании этого сформируем итоговый план действий работы с пропущеннными значениями

# %%
pd.DataFrame(round(data.isna().mean()*100,1)).style.background_gradient('coolwarm')

# %% [markdown]
# При обработке пропущенных значений в столбцах будем исходить из следующей логики:
#
# - **hours**:  Кол-во пропусков: 536 шт. В данном столбце содержится  информация о днях и часах работы. Заполнить пропуски аргументированными значениями по данному столбцу не является возможным. Мы не сможем узнать график работы заведений,так как график индвидуален и зависит от множества факторов.Заполнив пропуски синтетическими данными по данному столбцу мы исказим данные, так как они почти всегда выдуманные и ошибочные.Возможная причина возникновения пропусков - это техническая ошибка при формировании таблицы с исходными данными (либо некий сбой во время выгрузки данных на анализ, либо при объединении данных в единый файл, который также должен был передаваться на анализ).Также возможная причина пропусков заключается в том,что данные не были добавлены пользователями/меджементом заведения в сервис Яндекс Бизнес или в иной источник. Для избежания потери важной информации удалять строки с пропущенными значениями  не будем. Для удобства дальнейшей работы, пропуски в данном столбце `заменим на значение unknown`
#
#
# - **price**:  Кол-во пропусков: 5091 шт. В данном столбце содержится  информация о категорих цен в заведении, например «средние», «ниже среднего», «выше среднего». Заполнить пропуски аргументированными значениями по данному столбцу не является возможным. Каждое заведение уникально по своему. В определённой локации ценообразование заведения может считаться выше среднего, а в другом ниже среднего по рынку общепита.У каждого заведения разная проходимость, соответственно разная выборка.Тем более, что значения этого поля носят субъективный характер. Информация, размещённая в сервисе Яндекс Бизнес, могла быть добавлена пользователями или найдена в общедоступных источниках.Возможная причина возникновения пропусков - это техническая ошибка при формировании таблицы с исходными данными (либо некий сбой во время выгрузки данных на анализ, либо при объединении данных в единый файл, который также должен был передаваться на анализ).Также возможная причина пропусков заключается в том,что данные не были добавлены пользователями/меджементом заведения в сервис Яндекс Бизнес или в иной источник.Для избежания потери важной информации удалять строки с пропущенными значениями  не будем. Для удобства дальнейшей работы, пропуски в данном столбце `заменим на значение unknown`
#
#
# - **avg_bill**:  Кол-во пропусков: 4590 шт. В данном столбце содержится  информация о средней стоимости заказа в виде диапазона. Заполнить пропуски аргументированными значениями по данному столбцу не является возможным.Для заполения пропусков, нам необходима информация чеков покупок клиентов конкретного заведения, которой нет.Заполнив пропуски синтетическими данными по данному столбцу мы исказим данные, так как они почти всегда выдуманные и ошибочные.Возможная причина возникновения пропусков - это техническая ошибка при формировании таблицы с исходными данными (либо некий сбой во время выгрузки данных на анализ, либо при объединении данных в единый файл, который также должен был передаваться на анализ).Также возможная причина пропусков заключается в том,что данные не были добавлены пользователями/меджементом заведения в сервис Яндекс Бизнес или в иной источник.Для избежания потери важной информации удалять строки с пропущенными значениями  не будем. Для удобства дальнейшей работы, пропуски в данном столбце `заменим на значение unknown`
#
#
# - **middle_avg_bill**:  Кол-во пропусков: 5257 шт. В данном столбце содержится  информация о  среднем чеке, которая указана только для значений из столбца avg_bill, начинающихся с подстроки «Средний счёт».Если в столбце avg_bill отсутствует информация о среднем счёте, то пропуски мы не заполним,соответственно. Заполнить пропуски аргументированными значениями по данному столбцу не является возможным.Для заполения пропусков, нам необходима информация чеков покупок клиентов конкретного заведения, которой нет.Заполнив пропуски синтетическими данными по данному столбцу мы исказим данные, так как они почти всегда выдуманные и ошибочные.Возможная причина возникновения пропусков - это техническая ошибка при формировании таблицы с исходными данными (либо некий сбой во время выгрузки данных на анализ, либо при объединении данных в единый файл, который также должен был передаваться на анализ).Также возможная причина пропусков заключается в том,что данные не были добавлены пользователями/меджементом заведения в сервис Яндекс Бизнес или в иной источник. `Пропуски по данному столбцу оставляем.`
#
#
# - **middle_coffee_cup**:  Кол-во пропусков: 7871 шт. В данном столбце содержится  информация о  средней цене одной чашки капучино, которая указана только для значений из столбца avg_bill, начинающихся с подстроки «Цена одной чашки капучино».Если в столбце avg_bill отсутствует информация о средней цене, то пропуски мы не заполним,соответственно. Заполнить пропуски аргументированными значениями по данному столбцу не является возможным.Для заполения пропусков, нам необходима информация чеков покупок клиентов конкретного заведения, которой нет.Заполнив пропуски синтетическими данными по данному столбцу мы исказим данные, так как они почти всегда выдуманные и ошибочные.Возможная причина возникновения пропусков - это техническая ошибка при формировании таблицы с исходными данными (либо некий сбой во время выгрузки данных на анализ, либо при объединении данных в единый файл, который также должен был передаваться на анализ).Также возможная причина пропусков заключается в том,что данные не были добавлены пользователями/меджементом заведения в сервис Яндекс Бизнес или в иной источник. `Пропуски по данному столбцу оставляем.`
#
# - **seats**:  Кол-во пропусков: 3611 шт. В данном столбце содержится  информация о количество посадочных мест.Заполнить пропуски аргументированными значениями по данному столбцу не является возможным. Каждое заведение имеет разную площадь и организационный формат помещения.Заполнив пропуски синтетическими данными по данному столбцу мы исказим данные, так как они почти всегда выдуманные и ошибочные.Возможная причина возникновения пропусков - это техническая ошибка при формировании таблицы с исходными данными (либо некий сбой во время выгрузки данных на анализ, либо при объединении данных в единый файл, который также должен был передаваться на анализ).Также возможная причина пропусков заключается в том,что данные не были добавлены пользователями/меджементом заведения в сервис Яндекс Бизнес или в иной источник. `Пропуски по данному столбцу оставляем.`

# %% [markdown]
# **Замена пропусков по столбцу hours**

# %%
data['hours'].fillna('unknown',inplace=True)

# %% [markdown]
# **Замена пропусков по столбцу price**

# %%
data['price'].fillna('unknown',inplace=True)

# %% [markdown]
# **Замена пропусков по столбцу avg_bill**

# %%
data['avg_bill'].fillna('unknown',inplace=True)

# %% [markdown]
# Проверка после обработки пропусков

# %%
data.isna().sum()

# %% [markdown]
# По отобранным столбцам пропуски заменены на заглушки `unknown`

# %% [markdown]
# ###  Обработка явных  дубликатов

# %% [markdown]
# Для дальнейшей работы с данными найдем возможные явные дубликаты в датафрейме.

# %%
data.duplicated().sum()

# %% [markdown]
# В датафрейме **data** явные дубликаты не найдены

# %% [markdown]
# ###  Обработка неявных  дубликатов

# %% [markdown]
# Для дальнейшей работы с данными найдем возможные неявные дубликаты в датафрейме совпадающие по названию заведения,адресу и средней стоимости заказа в виде диапазона одновременно. Для этого предварительно преобразуем значения в столбцах, уберём лишние пробелы, символы, приведём к одному регистру.

# %%
def clean_name(row):
    
    return re.sub(r'[^а-яА-ЯёЁa-zA-Z0-9 ]', '', row['name']).strip().lower()

data['name'] = data.apply(clean_name, axis=1)


def clean_address(row):
    
    return re.sub(r'[^а-яА-ЯёЁa-zA-Z0-9 ]', '', row['address']).strip().lower()

data['address'] = data.apply(clean_address, axis=1)

# %% [markdown]
# После преобразований найдем  дубликаты в датафрейме совпадающие по названию,адресу и средней стоимости заказа в виде диапазона одновременно.

# %%
data[data.duplicated(subset=['name', 'address','avg_bill'], keep=False)]

# %% [markdown]
# Удалим строки, где есть повторяющиеся значения в столбцах 'name', 'address','avg_bill' и оставим первую встретившуюся строку с повтором.

# %%
data.drop_duplicates(subset=['name', 'address','avg_bill'], keep='first', inplace=True)

# %% [markdown]
# Проверка результата

# %%
data[data.duplicated(subset=['name', 'address','avg_bill'], keep=False)]

# %% [markdown]
# Дубликаты устранены

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# Ранее мы определили, что в столбце `seats` неверный тип данных и хотели изменить тип данных на формат целого числа int.Однако наличие пропусков не даёт нам возможность измененения.По этой причине оставляем формат `float64`

# %% [markdown]
# ### Обработка аномальных значений

# %%
data.head(5)

# %% [markdown]
# В рамках исследования найдём возможные аномальные значения по столбцам:

# %% [markdown]
# **Поиск аномалий по столбцу category**

# %%
data['category'].unique()

# %% [markdown]
# Аномалия не выявлены

# %% [markdown]
# **Поиск аномалий по столбцу address**

# %%
# Убраем ограничение на количество отображаемых строк
pd.set_option('display.max_rows', None) 

print(data['address'].value_counts())

# Восстанавливаем предыдущее ограничение
pd.reset_option('display.max_rows')

# %% [markdown]
# Предварительно аномалия не выявлены

# %% [markdown]
# **Поиск аномалий по столбцу district**

# %%
data['district'].unique()

# %% [markdown]
# Аномалия не выявлены

# %% [markdown]
# **Поиск аномалий по столбцу hours**

# %%
# Убраем ограничение на количество отображаемых строк
pd.set_option('display.max_rows', None) 

print(data['hours'].value_counts())

# Восстанавливаем предыдущее ограничение
pd.reset_option('display.max_rows')

# %% [markdown]
# Предварительно аномалия не выявлены

# %% [markdown]
# **Поиск аномалий по столбцу lat**

# %%
data['lat'].describe()

# %% [markdown]
# Аномалия не выявлены

# %% [markdown]
# **Поиск аномалий по столбцу lng**

# %%
data['lng'].describe()

# %% [markdown]
# Аномалия не выявлены

# %% [markdown]
# **Поиск аномалий по столбцу rating**

# %%
data['rating'].describe()

# %% [markdown]
# Аномалия не выявлены

# %% [markdown]
# **Поиск аномалий по столбцу price**

# %%
data['price'].unique()

# %% [markdown]
# Аномалия не выявлены

# %% [markdown]
# **Поиск аномалий по столбцу avg_bill**

# %%
# Убраем ограничение на количество отображаемых строк
pd.set_option('display.max_rows', None) 

print(data['avg_bill'].value_counts())

# Восстанавливаем предыдущее ограничение
pd.reset_option('display.max_rows')

# %% [markdown]
# Предварительно аномалия не выявлены

# %% [markdown]
# **Поиск аномалий по столбцу middle_avg_bill**

# %%
data['middle_avg_bill'].describe()

# %% [markdown]
# Для начала сделаем срез заведений со средним чеком менее 150 ₽.

# %%
data[data['middle_avg_bill']<150]

# %% [markdown]
# Заведение под названием "кофемания" расположенное по адресу москва улица новый арбат 19 имеет средний чек в размере 0 ₽. Тут явная ошибка в данных. В дальнейшем уберём данное заведение из нашего анализа. По остальным заведениям средний чек соответствует.

# %%
data.drop(index=3688,inplace=True)

# %% [markdown]
# Аналогично сделаем срез заведений со средним чеком более и равным 5000 ₽.

# %%
data[data['middle_avg_bill']>=5000]

# %% [markdown]
# Заведение под названием "крошка картошка" расположенное по адресу москва щёлковское шоссе вл75 имеет средний чек в размере 5500 ₽. Тут явная ошибка в данных.Заведение в категории "быстрое питание" не может иметь столь большой средний чек, тем более расположенное не в ЦАО. В дальнейшем уберём данное заведение из нашего анализа. По остальным заведениям средний чек соответствует.

# %%
data.drop(index=2795,inplace=True)

# %% [markdown]
# **Поиск аномалий по столбцу middle_coffee_cup**

# %%
data['middle_coffee_cup'].describe()

# %% [markdown]
# Посмотрим на заведения с ценой одной чашки капучино более 1000 ₽.

# %%
data[data['middle_coffee_cup']>1000]

# %% [markdown]
# В кофейне `шоколадница` по адресу москва большая семёновская улица 27 корп 1 очень высокая средняя цена за чашку капучино. Тут явная ошибка в данных. В дальнейшем уберём данное заведение из нашего анализа.

# %%
data.drop(index=2859,inplace=True)

# %% [markdown]
# **Поиск аномалий по столбцу chain**

# %%
data['chain'].describe()

# %% [markdown]
# Аномалия не выявлены

# %% [markdown]
# **Поиск аномалий по столбцу seats**

# %%
data['seats'].describe()

# %% [markdown]
# Для начала сделаем срез заведений, где нулевое количество посадочных мест

# %%
data[data['seats']==0]

# %% [markdown]
# Вполне вероятно, что в этих заведениях отсутствуют посадочные места из-за формата заведения, не предусматривающего пребывание клиентов в нем. Как вариант, блюда на вынос

# %% [markdown]
# Теперь рассмотрим заведения с аномально большим кол-ом посадочных мест, от 600 мест и более.

# %%
data[data['seats']>=600]

# %% [markdown]
# Аномалия не выявлены. Заведения с большим кол-ом посадочных мест, могут оказаться банкетными залами или  заведениями с открытой верандой на летнее время.

# %% [markdown]
# ### Добавление столбцов

# %% [markdown]
# В рамках дальнейшего анализа есть необходимость в добавление столбца c названиями улиц, а также отдельного столбца с обозначением, что заведение работает ежедневно и круглосуточно (24/7).

# %% [markdown]
# #### Добавление столбца street

# %% [markdown]
# Для добавления столбца street с информацией о названиях улиц мы будем использовать регулярное выражение. Это регулярное выражение будет искать название города "москва", за которым следует название улицы. Результатом будет только название улицы без города и номера дома.

# %%
data['street'] = data['address'].str.extract(r'москва\s(.*?)\s\d+')

# %%
data.head(5)

# %% [markdown]
# Столбец street с названиями улиц успешно создан.

# %% [markdown]
# #### Добавление столбца is_24/7

# %% [markdown]
# Для добавления столбца is_24/7 с обозначением, что заведение работает ежедневно и круглосуточно мы должны создать функцию для определения, является ли строка "круглосуточно" и "ежедневно" частью рабочего расписания.

# %%
def is_24_7(row):
    return 'круглосуточно' in row.lower() and 'ежедневно' in row.lower()

# %% [markdown]
# Применим функцию к каждой строке в столбце и создадим новый столбец is_24/7

# %%
data['is_24/7'] = data['hours'].apply(is_24_7)

# %%
data['is_24/7'].value_counts()

# %% [markdown]
# Столбец is_24/7 с названиями улиц успешно создан.

# %% [markdown]
# **Вывод**
# - Пропуски в столбцах hours,price,avg_bill  заменены на значение unknown.
# - Пропуски в столбцах middle_avg_bill,middle_coffee_cup,seats оставлены без изменений
# - Явные дубликаты не выявлены
# - Аномальное значение в столбце middle_avg_bill, где заведение под названием "кофемания" расположенная по адресу москва улица новый арбат 19 имеет средний чек в размере 0 ₽ - устранено.
# - Аномальное значение в столбце middle_avg_bill, где заведение под названием "крошка картошка" расположенное по адресу москва щёлковское шоссе вл75 имеет средний чек в размере 5500 ₽ - устранено.
# - Аномальное значение в столбце middle_coffee_cup, где заведение под названием "шоколадница" расположенное по адресу москва большая семёновская улица 27 корп 1 имеет средний чек за чашку капучино в размере 1568 ₽ - устранено.
# - Добавлены:
#   - столбец street с названиями улиц
#   - столбец is_24/7 с обозначением, что заведение работает ежедневно и круглосуточно
# - Неявные дубликаты устранены

# %% [markdown]
# ##  Исследовательский анализ данных рынка общепита

# %% [markdown]
# В рамках дальнейшего анализа изучим и проверим полученные данные.Найдём зависимости и особенности заведений исходя из локации,категории и других параметров. Соберём наблюдения в один общий вывод.

# %% [markdown]
# ###  Распределение заведений по категориям

# %% [markdown]
# В рамках исследования узнаем какие категории заведений представлены в данных. Исследуем количество объектов общественного питания по категориям: рестораны, кофейни, пиццерии, бары и так далее. Построим визуализации. Ответим на вопрос о распределении заведений по категориям.

# %% [markdown]
# Найдём общее кол-во заведений после предобработки

# %%
len(data['name'])

# %% [markdown]
# Создадим сводную таблицу object_distribution в целях получения информации по кол-ву заведений и их рыночной доли в разрезе категорий

# %%
object_distribution = data.pivot_table(index='category',
                                       values='name',
                                       aggfunc='count').reset_index().sort_values(by='name',ascending=False)
object_distribution.columns=('category','count')
object_distribution['share_of_market%'] = round(object_distribution['count']/len(data['name'])*100,2)
object_distribution

# %% [markdown]
# Построим интерактивную столбчатую диаграмму для визуального представления полученных данных

# %%
# строим график
fig = px.bar(object_distribution, 
             x='category', 
             y='count',
             color='category',
             hover_data=['count', 'share_of_market%'],
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение заведений по категориям',
                  title_x=0.45,
                  xaxis_title='Категория заведений',
                  yaxis_title='Кол-во заведений',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# Лидерами рынка являются заведения в категории `кафе`,`ресторан`,`кофейня`. Доля кафе составляет ~ 28% от всего рынка общепита Москвы, всего заведений этой категории 2376 ед.С небольшим отставанием заведения в категории ресторан. Занимаемая доля рынка ~ 25%. всего заведений 2042 ед. Кофейня занимает 3-е место при 1410 ед. заведений и доли рынка в ~17%.Рыночная доля остальных категорий варьируется от 3 до 9%  по Москве. Меньше всего булочных, доля рынка всего ~3%

# %% [markdown]
# ###  Распределение посадочных мест по категориям заведений

# %% [markdown]
# Исследуем количество посадочных мест в местах по категориям: рестораны, кофейни, пиццерии, бары и так далее. Построим визуализации. Проанализируем результаты и сделаем выводы.

# %%
# строим график
fig = px.bar(data.pivot_table(index='category',
                              values='seats',
                              aggfunc='sum').reset_index().sort_values(by='seats',ascending=False), 
             x='category', 
             y='seats',
             color='category',
             text='seats',
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение посадочных мест по категориям заведений',
                  title_x=0.45,
                  xaxis_title='Категория заведений',
                  yaxis_title='Кол-во посадочных мест',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# Больше всего посадочных мест в заведениях Москвы категории:
# - ресторан (154681 мест)
# - кафе (118494 мест)
# - кофейня (83263 мест)
#
# Это не удивительно, заведений по этим категориям больше всего. Некоторые заведения этой категории имеют летние веранды.
#
# Меньше всего посадочных мест в булочной (13229 мест) и столовой (16359 мест).Данный формат заведений действительно не популярен в Москве.Тем более, что большинство булочных продают еду на вынос. Сравнив с  графиком 'Распределение заведений по категориям' можно найти прямую зависимость между кол-ом заведений и кол-ом посадочных мест.

# %% [markdown]
# Узнаем медианное распределение посадочных мест заведений по каждой категории. Для этого построим диаграмму размаха.

# %%
fig = px.box(data, 
             x='category', 
             y='seats',
             color='category',
             hover_data=data.columns,
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение посадочных мест по категориям заведений',
                  title_x=0.45,
                  xaxis_title='Категория заведений',
                  yaxis_title='Кол-во посадочных мест в одном заведении',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# По всем категориям наблюдаются серьезные выбросы. Однако, мы не можем утверждать, что у нас есть ошибки в данных, потому что, как уже было сказано, заведения с большим кол-ом посадочных мест, могут оказаться банкетными залами или заведениями с открытой верандой на летнее время. Мы наблюдаем большое кол-во заведений до 350 ед. посадочных мест. Рассмотрим их поближе.

# %% [markdown]
# <a id="Распределение"></a>

# %%
fig = px.box(data, 
             x='category', 
             y='seats',
             color='category',
             hover_data=data.columns,
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение посадочных мест по категориям заведений',
                  title_x=0.45,
                  xaxis_title='Категория заведений',
                  yaxis_title='Кол-во посадочных мест в одном заведении',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))


fig.update_yaxes(range=[0, 350])
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# Итак, можно заметить, что практически все категории заведений имеют ограничение по количеству посадочных мест, которое приближается к 300 ед(верхний ус). Медианные значения варьируются в пределах от 50 до 86 ед. в зависимости от категории заведения. В целом в заведениях категории: ресторан,кофейня,бар и столовая больше всего посадочных мест. Встречаются заведения категории кафе с аномально большим кол-ом посадочных мест, но медианное значение показывает, что большинство заведений имеют всего 60 мест. В булочных и пиццерийных всего 50 и 55 мест соответственно, формат этих заведений в основном работает на вынос и доставку.

# %% [markdown]
# ### Cоотношение сетевых и несетевых заведений

# %% [markdown]
# Рассмотрим и изобразим соотношение сетевых и несетевых заведений в датасете. Узнаем каких заведений больше.Для этого построим интерактивную круговую диаграмму

# %%
#Палитра цветов
pastel_colors = ['#55E6C1', '#FEA47F'] 

#Строим график
fig = go.Figure(data=[go.Pie(
                labels=['несетевое заведение', 'сетевое заведение'],
                values=data.groupby('chain')['chain'].count(),
                pull=[0.1, 0],
                marker=dict(colors=pastel_colors))])  # Указываем палитру цветов

#оформляем график
fig.update_layout(title='Cоотношение сетевых и несетевых заведений',
                  title_x=0.45,
                  width=1000, # указываем размеры графика
                  height=600,                  
                  title_font=dict(size=20),
                  annotations=[dict(
                                    x=1.15,
                                    y=1.05,
                                    text='Тип заведения',
                                    showarrow=False)])

fig.show()

# %% [markdown]
# Диаграмма показывает нам, что доля несетевых заведений по рынку общепита Москвы составляет 61.9%, абсолютное значение 5199 заведений. По сетевым заведениям доля 38.1% ,а кол-во 3199 заведений.

# %% [markdown]
# ###  Распределение сетевых заведений по категориям

# %% [markdown]
# Узнаем какие категории заведений чаще являются сетевыми. Исследуем данные и ответим на вопрос графиком.

# %% [markdown]
# Создадим сводную таблицу chain_distribution в целях получения информации по кол-ву сетевых заведений и их рыночной доли в разрезе категорий общепита.

# %%
chain_distribution = (data.pivot_table(index='category',
                                       values='name',
                                       aggfunc='count').reset_index().sort_values(by='name',
                                                                         ascending=False)).merge(data.query('chain == 1').pivot_table(index='category',
                                                                                                                                      values='name',
                                                                                                                                      aggfunc='count').reset_index().sort_values(by='name',ascending=False), on ='category')
chain_distribution.columns=('Категория заведения','Кол-во всех заведений','Кол-во сетевых заведений')
chain_distribution['Доля сетевых заведений от всех заведений по каждой категории%'] = round((chain_distribution['Кол-во сетевых заведений']/chain_distribution['Кол-во всех заведений']*100),2)
chain_distribution['Доля сетевых заведений от общего кол-ва сетевых заведений%'] = round((chain_distribution['Кол-во сетевых заведений']/len(data[data['chain'] == 1])*100),2)
chain_distribution

# %% [markdown]
# Построим интерактивную столбчатую диаграмму для визуального представления полученных данных

# %%
#Строим график
fig = px.bar(chain_distribution.sort_values(by='Кол-во сетевых заведений',ascending=False), 
             x='Категория заведения', 
             y='Кол-во сетевых заведений',
             color='Категория заведения',
             hover_data=['Кол-во сетевых заведений', 
                         'Доля сетевых заведений от всех заведений по каждой категории%',
                         'Доля сетевых заведений от общего кол-ва сетевых заведений%'],
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение сетевых заведений по категориям',
                  title_x=0.45,
                  xaxis_title='Категория заведений',
                  yaxis_title='Кол-во сетевых заведений',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# В разрезе сетевых заведений лидерами рынка являются заведения в категории `кафе`,`ресторан`,`кофейня`. Доля сетевых заведений от всех заведений по категории `кафе` составляет ~ 33% .Доля сетевых заведений от общего числа сетевых заведений в категории `кафе` составляет ~ 24%. Кол-во сетевых заведений этой категории 779 ед.
#
#
# С небольшим отставанием заведения в категории `ресторан`. Доля сетевых заведений от всех заведений в категории `ресторан` составляет ~ 36%.Доля сетевых заведений от общего числа сетевых заведений в категории `кафе` составляет ~ 23%. Всего заведений 729 ед.
#
#
# Кофейня занимает 3-е место при 717 ед. сетевых заведений. Доля сетевых заведений от всех в категории `кофейня` составляет ~ 51%.Доля сетевых заведений от общего числа сетевых в категории `кофейня` составляет ~ 22%.
#
#
# Рыночная доля всех остальных сетевых заведений от общего числа сетевых заведений варьируется от 2.75 до 10% по Москве.
#
# Меньше всего булочных и столовых.

# %% [markdown]
# ### Топ-15 популярных сетей в Москве

# %% [markdown]
# В рамках исследования найдём топ-15 популярных сетей в Москве, количество заведений в этой сети. Построим подходящую для такой информации визуализацию.Для этого создадим сводную таблицу top15_chain.

# %%
top15_chain = data.query('chain == 1').groupby('name').agg({'name':'count','category':'first'})
top15_chain.columns=['count','category']
top15_chain = top15_chain.sort_values(by='count',ascending=False).head(15)
top15_chain.reset_index(inplace=True)
top15_chain

# %% [markdown]
# Построим интерактивную столбчатую диаграмму для визуального представления полученных данных

# %%
#Строим график
fig = px.bar(top15_chain,
             x='name', 
             y='count',
             color='category',
             text = 'count',
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title=' Распределение топ-15 популярных сетей в Москве по категориям',
                  title_x=0.45,
                  xaxis_title='Название сети заведений',
                  yaxis_title='Количество заведений в сети',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# По полученному графику мы можем заметить, что большая часть сетевых заведений приходится на заведения категории кофейня. Лидером является сеть `шоколадница`с 119 заведениями по Москве.На `one price coffee` и `cofix` приходится 71 и 65 заведений соответственно.Всего 5 крупных сетей кофеен.
#
# По рынку заведений в категории ресторан и кафе существует 3 крупных сети на каждую  из категорий. Явным фаворитом среди ресторанов стала `яндекс лавка` с 69 заведениями. Среди кафе `кулинарная лавка братьев караваевых` с 39 заведениями
#
# Среди пиццерий две очень популярных сети. На `доминос пицца` в Москве приходится 76 заведений. На `додо пицца` 74 заведения.
#
# Из крупных сетевых ресторанов быстрого питания стала `хинкальная` c 44 заведениями. Из булочных сеть `буханка`.

# %% [markdown]
# ###  Распределение  заведений по категориям в разрезе административных районов

# %% [markdown]
# Узнаем какие административные районы Москвы присутствуют в датасете. Отобразим общее количество заведений и количество заведений каждой категории по районам.Проиллюстрируем эту информацию графиком heatmap.

# %% [markdown]
# Узнаем общее кол-во заведений по каждому административному району

# %%
data.pivot_table(index='district', 
                 values='name', 
                 aggfunc='count').sort_values(by='name',ascending=False)

# %% [markdown]
# Центральный округ, несомненно, лидирует по количеству заведений, в то время как на Северо-западе сфера общественного питания испытывает трудности. По остальным районам явно перекоса нет.

# %% [markdown]
# Создадим сводную таблицу district_distribution в целях получения информации по кол-ву заведений  в разрезе категорий и административных районов

# %%
district_distribution = data.pivot_table(index='category', 
                                         columns='district', 
                                         values='name', 
                                         aggfunc='count')
district_distribution

# %% [markdown]
# По полученной матричной таблице легко найти точное кол-во заведений по конеретному округу и категории заведения.Посмотрим в каких ячейчках наблюдаются большое или маленькое значение числа заведений.

# %% [markdown]
# Построим тепловую карту для визуального представления полученных данных

# %%
#Строим график
fig = go.Figure(data=go.Heatmap(z=district_distribution.values,
                                x=district_distribution.columns,
                                y=district_distribution.index,
                                colorscale='YlGnBu',
                                ))

# оформляем график
fig.update_layout(title='Распределение заведений в разрезе категорий и административных районов',
                  title_x=0.5,
                  xaxis_title='Административный район',
                  yaxis_title='Категория заведения',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# Следует учесть, что во всех районах, за исключением центрального, категория `кафе` лидирует по количеству заведений. В центральном районе, напротив, рестораны занимают первое место. Следует также отметить, что распределение заведений по категориям в различных административных районах довольно схоже между собой, за исключением Центрального и Северо-Западного районов Москвы, которые выделяются в этом отношении.

# %% [markdown]
# Дополним наш анализ интерактивной столбчатой диаграммой

# %%
district_distribution = data.pivot_table(index='district', 
                                         columns='category', 
                                         values='name', 
                                         aggfunc='count')
district_distribution

# %%
#Строим график
fig = px.bar(district_distribution,
             x=district_distribution.columns, 
             y=district_distribution.index,
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение заведений в разрезе категорий и административных районов',
                  title_x=0.45,
                  xaxis_title='Кол-во заведений',
                  yaxis_title='Административный район',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# ЦАО выделяется большим кол-ом заведений абсолютно по всем категориям в абсолютном значении в 2241 заведения. САО,ЮАО и СВАО практически идентичны по числу заведений. На Северо-западе сфера общественного питания испытывает трудности. Там всего 409 заведений

# %% [markdown]
# ### Распределение  рейтингов по категориям заведений

# %% [markdown]
# Узнаем распределение средних рейтингов по категориям заведений. Для этого построим график violinplot. Этот график характеризует форму распределения значений.Также с помощью этого графика мы получим информацию по медианному и среднему значению рейтингов каждой категории общепита.

# %%
#Строим график
fig = px.violin(data, 
                y='rating', 
                x='category', 
                color='category',
                box=True, 
                hover_data=data.columns,
                color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение  рейтингов по категориям заведений',
                  title_x=0.45,
                  xaxis_title='Категория заведения',
                  yaxis_title='Рейтинг',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))


# оформляем график
fig.update_traces(meanline_visible=True)
fig.update_yaxes(zeroline=False)
fig.update_xaxes(tickangle=45)
fig.show()

# %% [markdown]
# По всем категориям общепита наблюдаются выбросы с низкими оценками по отдельно взятым заведениям.Особенно много выбросов по заведениям в категории кафе,ресторан и быстрое питание.Детальная информация доступна при наведении курсора на любой из выбросов. Основные значения рейтинга варьируются от 3.9 до 4.6.Рассмотрим распределения в крупном масштабе.

# %%
#Строим график
fig = px.violin(data, 
                y='rating', 
                x='category', 
                color='category',
                box=True, 
                hover_data=data.columns,
                color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение  рейтингов по категориям заведений',
                  title_x=0.45,
                  xaxis_title='Категория заведения',
                  yaxis_title='Рейтинг',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))




# оформляем график
fig.update_traces(meanline_visible=True)
fig.update_yaxes(zeroline=False)
fig.update_xaxes(tickangle=45)
fig.update_yaxes(range=[3.5, 5])
fig.show()

# %% [markdown]
# По полученному графику можно заметить следующее:
# - Бары,пабы получают чаще остальных высокий рейтинг от посетителей, где медианное значение 4.4, а среднее 4.38.
# - Булочная,кофейня,пиццерия,ресторан и столовая получили медианный рейтинг 4.3, среднее варьируется от 4.21 до 4.30
# - Заведения быстрого питания  и кафе получили медианный рейтинг 4.2, среднее варьируется от 4.05 до 4.12

# %% [markdown]
# Дополним наше исследование и рассмотрим распределение рейтингов по категориям заведений на графике boxplot

# %%
#Строим график
fig = px.box(data, 
                y='rating', 
                x='category', 
                color='category', 
                hover_data=data.columns,
                color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение  рейтингов по категориям заведений',
                  title_x=0.45,
                  xaxis_title='Категория заведения',
                  yaxis_title='Рейтинг',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))




# оформляем график
fig.update_yaxes(zeroline=False)
fig.update_xaxes(tickangle=45)
fig.update_yaxes(range=[3.5, 5])
fig.show()

# %% [markdown]
# В целом сильного отклонения между медианным и среднем значением рейтинга заведений нет. Это говорит нам о том, что заведения с аномально большим или маленьким рейтингом в данных отсутствуют. Однако есть исключение. Медианное значение заведений быстрого питания составляет 4.2, а среднее 4.05, значит в данных есть заведения с очень плохим рейтингом, влияющих на среднее значение выборки.

# %% [markdown]
# Продемонстрируем разницу среднего и медианного значения в виде таблицы

# %%
data.pivot_table(index='category',aggfunc={'rating':['mean','median']})

# %% [markdown]
# Таблица полностью подтверждает наши наблюдения

# %% [markdown]
# ### Фоновая картограмма  со средним рейтингом заведений каждого района

# %% [markdown]
# В рамках дальнейшего исследования построим фоновую картограмму (хороплет) со средним рейтингом заведений каждого района.

# %% [markdown]
# Чтобы присвоить каждому району средний рейтинг, мы должны создать сводную таблицу `rating_district`

# %%
rating_district = data.groupby('district', as_index=False)['rating'].agg('mean')
rating_district

# %%
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='openstreetmap')

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=geo_json,
    data=rating_district,
    columns=['district', 'rating'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Средний рейтинг заведений по районам',
).add_to(m)

# выводим карту
m

# %% [markdown]
# На представленном хороплёте видно явное лидерство ЦАО с средним рейтингом заведений в 4.38. Высокий рейтинг заведений также по САО и СЗАО в диапазоне 4.2 - 4.24. ЮВАО отличился низким рейтингом заведений,среднее значение 4.1. По остальным районам наблюдается устойчивое значение в диапазоне 4.14 - 4.18

# %% [markdown]
# ### Распределение заведений на карте

# %% [markdown]
# Отобразим все заведения датасета на карте с помощью кластеров средствами библиотеки folium

# %%
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='openstreetmap')

# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
data.apply(create_clusters, axis=1)

# выводим карту
m

# %% [markdown]
# На карте отчётливо видно большое скопление общепита.В целом престижность района определяет кол-во и качество расположенных в нём заведений.

# %% [markdown]
# ###  Распределение  заведений по категориям в разрезе городских улиц

# %% [markdown]
# Найдём топ-15 улиц по количеству заведений. Построим график распределения количества заведений и их категорий по этим улицам.

# %% [markdown]
# Создадим сводную таблицу `agg_data_street` с информацией о кол-ве заведений общепита в разрезе городских улиц и категорий. Найдём топ-15 улиц по количеству заведений.

# %%
agg_data_street = (data.pivot_table(index='street', 
                                    values='name', 
                                    aggfunc='count').sort_values(by='name',ascending=False).head(15)).merge((data.pivot_table(index='street', 
                                                                                                                              columns='category', 
                                                                                                                              values='name', 
                                                                                                                              aggfunc='count')), 
                                                                                                             on='street')
agg_data_street.drop(columns='name',inplace=True)
agg_data_street

# %% [markdown]
# Мы нашли топ-15 улиц, где находится больше всего заведений общепита и добавили разрез по категориям. Построим heatmap для лучшего понимания распределения заведений по улицам.

# %%
#Строим график
fig = go.Figure(data=go.Heatmap(z=agg_data_street.values,
                                x=agg_data_street.columns,
                                y=agg_data_street.index,
                                colorscale='YlGnBu',
                                ))

#оформляем график
fig.update_layout(title='Распределение заведений по категориям в разрезе городских улиц',
                  title_x=0.55,
                  xaxis_title='Категория заведения',
                  yaxis_title='Название улицы',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show()

# %% [markdown]
# На фоне остальных сильно выделяется Проспект мира,Профсоюзная улица и Ленинский проспект. Все они обладают большой протяжённостью. Также самые часто встречаемые заведения абсолютно по всем улицам это кафе,кофейни и рестораны. По некоторым улицам, шоссе вовсе отсутствуют булочные,пиццерии и столовые.

# %% [markdown]
# <a id="Распределение_"></a>

# %%
# Создание графика
fig = px.bar(agg_data_street.reset_index(), 
             x=agg_data_street.columns[1:], 
             y='street', 
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение заведений по категориям в разрезе городских улиц',
                  title_x=0.45,
                  xaxis_title='Кол-во заведений',
                  yaxis_title='Название улицы',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))


fig.show() # выводим график

# %% [markdown]
# Мы дополнили нашу тепловую карту столбчатой диаграммой. Теперь нам нагляднее видно занимаемые доли категорий заведений по топ 15 улиц. Только на Проспекте мира и Профсоюзной улице оказалось более 100 заведений. На Пятницкой улице и улице Миклухо-Маклая менее 50 заведений общепита. По остальным улицам,проспектам, шоссе численность находится в диапазоне от 50 до 100 заведений. Доли категорий заведений на каждой улице индвидуальны и зависят от территориального расположения отдельно взятой улицы.

# %% [markdown]
# ### Городские улицы с одним объектом общепита

# %% [markdown]
# Для дальнейшего исследования найдём улицы, на которых находится только один объект общепита. Детально рассмотрим их. Для этого создадим сводную таблицу `one_object_street`

# %%
one_object_street = data.pivot_table(index=['street', 'district'], 
                                     values=['name', 'category'], 
                                     aggfunc={'name':'count', 'category':'first'}
                                     ).reset_index().sort_values(by='name', ascending=False).query('name == 1')


one_object_street.columns=('street','district','category','count')
one_object_street

# %% [markdown]
# Всего найдено 444 улиц с одним объектом общепита. Построим карту на которой отразим кластеры с заведениями, которые находятся в единственном экземпляре на городской улице

# %%
# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='openstreetmap')

# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
one_object_street.merge(data, on='street').apply(create_clusters, axis=1)

# выводим карту
m

# %% [markdown]
# Большинство заведений одиночек расположено в ЦАО, там больше всего улиц с одним заведением общепита.На окраинах Москвы улиц с единственным заведением достаточно немного.

# %% [markdown]
# Найдём точное кол-во заведений в разрезе округов и категорий общепита по городским улицам с одним объектом общепита. Для этого воспользуемся уже ранее созданной таблицей one_object_street

# %%
one_object_street = one_object_street.pivot_table(index=['district','category'],
                                                  values='count',
                                                  aggfunc=({'count':'sum'})).reset_index().sort_values(by='count',ascending=False)

one_object_street

# %% [markdown]
# Построим столбчатую диаграмму для  понимания распределения объектов по улицам с единственным заведением в разрезе округов и категорий

# %%
#Строим график
fig = px.bar(one_object_street, 
             x='count', 
             y='district',
             color='category',
             orientation='h',
             color_discrete_sequence=px.colors.qualitative.Pastel)
# оформляем график
fig.update_layout(title='Распределение заведений на улицах с одним объектом общепита по округам',
                  title_x=0.45,
                  xaxis_title='Кол-во заведений',
                  yaxis_title='Округ Москвы',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# Как видно, почти на  140 улиц в ЦАО находится только одно заведение общепита. Большинство заведений категории ресторан,кафе,кофейня.В ЮЗАО и СЗАО меньше всего улиц с одним заведением. Кафе наиболее популярный общепит по всем округам за исключением СЗАО и ЦАО.В этих округах на улицах с одним объектом общепита чаще находятся рестораны.

# %% [markdown]
# ### Распределение медианного значения средних чеков заведений по округам

# %% [markdown]
# Посчитаем медиану  столбца `middle_avg_bill` для каждого округа. Используем это значение в качестве ценового индикатора округа. Построим фоновую картограмму (хороплет) с полученными значениями для каждого района. Проанализируем цены в центральном административном округе и других. Найдём зависимости.

# %%
median_bill_district = data.pivot_table(index='district',
                                        values='middle_avg_bill',
                                        aggfunc={'middle_avg_bill':'median'}).reset_index()

median_bill_district.columns=('district','median_bill')
median_bill_district.sort_values(by='median_bill',ascending=False)

# %% [markdown]
# Построим хороплёт

# %%
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='openstreetmap')

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=geo_json,
    data=median_bill_district,
    columns=['district', 'median_bill'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Распределение медианного значения средних чеков по округам',
).add_to(m)

m

# %% [markdown]
# Средний чек заведения в разрезе округов Москвы коррелирует с престижностью районов Москвы и стоимостью квадратного метра. На данном [изображении](https://ya.ru/images/search?from=tabbar&img_url=https%3A%2F%2Fic.pics.livejournal.com%2Fdmitry424%2F44466331%2F40009%2F40009_original.jpg&lr=121830&pos=4&rpt=simage&text=%D0%B2%20%D0%BA%D0%B0%D0%BA%D0%BE%D0%BC%20%D0%BE%D0%BA%D1%80%D1%83%D0%B3%D0%B5%20%D0%BC%D0%BE%D1%81%D0%BA%D0%B2%D1%8B%20%D0%B1%D0%BE%D0%BB%D1%8C%D1%88%D0%B5%20%D0%B2%D1%81%D0%B5%D0%B3%D0%BE%20%D1%83%D0%BB%D0%B8%D1%86) это отчетливо видно.
# Самыми платёжеспособными оказались посетители ЗАО и ЦАО, их средний чек составил 1000 руб.Далее следует СЗАО с средним чеком в 700 руб. По остальным округам средний чек находится в диапазоне 500 - 650 руб. Меньше всего платят посетители ЮВАО.

# %% [markdown]
# **Вывод**
#
# Мы провели исследовательский анализ данных рынка общепита и нашли некоторые особенности, зависимости.
#
# 1. Общее кол-во заведений в Москве составило 8398 ед.
#
#
# 2.  Лидерами рынка являются заведения в категории кафе,ресторан,кофейня. Доля кафе составляет ~ 28% от всего рынка общепита Москвы, всего заведений этой категории 2376 ед. Занимаемая доля рынка ресторанов ~ 25%. всего заведений 2042 ед. Кофейня занимает 3-е место при  1410  ед. заведений и доли рынка в ~17%.Рыночная доля остальных категорий варьируется от 3 до 9% по Москве. Меньше всего булочных, доля рынка всего ~3%.
#
#
#
# 3. Существует прямая зависимость между кол-ом заведений и кол-ом посадочных мест.Медианна числа посадочных мест на одно заведение варьируется в пределах от 50 до 86 ед. в зависимости от категории заведения.В заведениях категории: ресторан,кофейня,бар и столовая больше всего посадочных мест.Подробное распределение кол-ва посадочных мест [здесь](#Распределение)
#
#
# 4. Доля несетевых заведений по рынку общепита Москвы составляет 61.9%, абсолютное значение 5199 заведений. По сетевым заведениям доля 38.1% ,а кол-во 3199 заведений.
#
# 5. В разрезе сетевых заведений лидерами рынка являются заведения в категории `кафе`,`ресторан`,`кофейня`.
#
#   - Доля сетевых заведений от всех заведений по категории `кафе` составляет ~ 33% .Доля сетевых заведений от общего числа сетевых заведений  составляет ~ 24%. Кол-во сетевых заведений этой категории 779 ед.
#
#
#   - Доля сетевых заведений от всех заведений в категории `ресторан` составляет ~ 36%.Доля сетевых заведений от общего числа сетевых заведений  составляет ~ 23%. Всего заведений 729 ед.
#
#
#   - Доля сетевых заведений от всех в категории `кофейня` составляет ~ 51%.Доля сетевых заведений от общего числа сетевых заведений составляет ~ 22%.Всего заведений 717 ед.
#
#   - Рыночная доля всех остальных сетевых заведений от общего числа сетевых заведений варьируется от 2.75 до 10% по Москве. Меньше всего булочных и столовых.
#
# - Большая часть сетевых заведений приходится на заведения категории кофейня. Лидером является сеть шоколадница с 119 заведениями по Москве.На one price coffee и cofix приходится 71 и 65 заведений соответственно.Всего 5 крупных сетей кофеен.
#
# 6. На рынке ресторанов и кафе выделяются три крупные сети в каждой из этих категорий. `Яндекс.Лавка` с 69 заведениями лидирует среди ресторанов, а в сегменте кафе - `Кулинарная Лавка братьев Караваевых` с 39 заведениями. В сфере пиццерий две популярные сети, `Доминос Пицца` с 76 заведениями и `Додо Пицца` с 74 заведениями. Среди крупных сетей быстрого питания выделяется `Хинкальная` с 44 заведениями, а среди булочных - сеть `Буханка`.
#
# 7. В ЦАО больше всего кол-во заведений (2241 ед.), а в СЗАО меньше всего (409 ед.). Во всех округах, за исключением центрального, категория `кафе` лидирует по количеству заведений. В центральном районе, напротив, `рестораны` занимают первое место.
#
# 8. Основные значения рейтинга варьируются от 3.9 до 4.6
# - Бары,пабы получают чаще остальных высокий рейтинг от посетителей, где медианное значение 4.4, а среднее 4.38.
# - Булочная,кофейня,пиццерия,ресторан и столовая получили медианный рейтинг 4.3, среднее варьируется от 4.21 до 4.30
# -  Заведения быстрого питания  и кафе получили медианный рейтинг 4.2, среднее варьируется от 4.05 до 4.12
#
# 9. Средний рейтинг заведений по округам:
# - В ЦАО 4.38
# - В САО и СЗАО в диапазоне 4.2 - 4.24
# - ЮВАО отличился низким рейтингом заведений,среднее значение 4.1.
# - По остальным районам наблюдается устойчивое значение в диапазоне 4.14 - 4.18
#
# 10. Мы нашли [топ-15](#Распределение_) улиц по кол-ву заведений.На Проспекте мира и Профсоюзной улице оказалось более 100 заведений. На Пятницкой улице и улице Миклухо-Маклая менее 50 заведений общепита. По остальным улицам,проспектам, шоссе численность находится в диапазоне от 50 до 100 заведений. Доли категорий заведений на каждой улице индвидуальны и зависят от территориального расположения отдельно взятой улицы.
#
# 11. Самыми платёжеспособными оказались посетители ЗАО и ЦАО, их средний чек составил 1000 руб.Далее следует СЗАО с средним чеком в 700 руб. По остальным округам средний чек находится в диапазоне 500 - 650 руб. Меньше всего платят посетители ЮВАО

# %% [markdown]
# ## Исследование рынка кофеен

# %% [markdown]
# Основатели фонда «Shut Up and Take My Money хотят открыть кофейню в Москве.Наша задача исследовать рынок кофеен и дать рекомендацию для открытия нового заведения.

# %% [markdown]
# ### Распределение кофеен по округам

# %% [markdown]
# Узнаем сколько всего кофеен в датасете и в каких районах их больше всего.

# %% [markdown]
# Для начала создадим исходную таблицу `data_coffee_house` с информацией о заведениях категории кофейня

# %%
data_coffee_house = data[data['category'] == 'кофейня']
data_coffee_house.head(5)

# %%
print(f'Всего представлено {len(data_coffee_house)} кофеен в датасете')

# %% [markdown]
# Создадим сводную таблицу `coffee_district_distribution` с информацией о кол-ве кофеен распределённых по округам.

# %%
coffee_district_distribution = data_coffee_house.pivot_table(index='district',
                                                             values='name',
                                                             aggfunc={'name':'count'}).reset_index().sort_values(by='name',ascending=False)
coffee_district_distribution.columns=('district','count')
coffee_district_distribution['share_of_coffee_house%'] = round(coffee_district_distribution['count']/len(data_coffee_house)*100,2)
coffee_district_distribution

# %% [markdown]
# Построим интерактивную столбчатую диаграмму для визуального представления полученных данных

# %%
# строим график
fig = px.bar(coffee_district_distribution, 
             x='district', 
             y='count',
             color='district',
             hover_data=['count', 'share_of_coffee_house%'],
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение кофеен по округам',
                  title_x=0.45,
                  xaxis_title='Административный район',
                  yaxis_title='Кол-во кофеен',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# В ЦАО представлено 427 кофеен, это ~30% от всех кофеен Москвы.Это не удивительно, большой трафик офисного персонала,туристов и просто прогуливающихся людей рождает спрос на такого рода заведения.По всем остальным округам мы видим гораздо меньшее кол-во кофеен.Удивительно, что даже в престижных округах Москвы и в округах с большим кол-ом высших учебных заведений достаточно небольшое кол-во кофеен по сравнению с Москвой. Так, например, в ЗАО 150 кофеен, ЮЗАО 96, а в СЗАО меньше всех, всего 62 кофейни.

# %% [markdown]
# ### Распределение круглосуточных кофеен

# %% [markdown]
# Узнаем сколько всего круглосуточных кофеен, соотношение кофеен с фикс. графиком и круглосуточных кофеен. Детально рассмотрим их. Построим график распределения  круглосуточных кофеен по административным округам.

# %%
print(f" Всего представлено {len(data_coffee_house[data_coffee_house['is_24/7'] == True])} круглосуточных кофеен")

# %% [markdown]
# Найдём соотношение кофеен с фикс. графиком и круглосуточных кофеен. Для этого построим круговую диаграмму

# %%
#Палитра цветов
pastel_colors = ['#55E6C1', '#FEA47F'] 

#Строим график
fig = go.Figure(data=[go.Pie(
                labels=['Кофейни с фикс. графиком', 'Круглосуточные кофейни'],
                values=data_coffee_house.groupby('is_24/7')['is_24/7'].count(),                
                marker=dict(colors=pastel_colors))])  # Указываем палитру цветов

#оформляем график
fig.update_layout(title='Соотношение кофеен с фикс. графиком и круглосуточных кофеен',
                  title_x=0.45,
                  width=1000, # указываем размеры графика
                  height=600,                  
                  title_font=dict(size=20),
                  annotations=[dict(
                                    x=1.15,
                                    y=1.05,
                                    text='График работы',
                                    showarrow=False)])

fig.show()

# %% [markdown]
# Занимаемая рыночная доля круглосуточных кофеен всего 4.11 % при абсолютной численности в 58 заведений.

# %% [markdown]
# Теперь посмотрим как распределены круглосуточные кофейни по административным округам

# %%
coffee_house_24_7 = data_coffee_house[data_coffee_house['is_24/7'] == True].pivot_table(index='district', 
                                                                                        values='name', 
                                                                                        aggfunc='count').sort_values(by='name',ascending=False).reset_index()

coffee_house_24_7.columns=('district','count')
coffee_house_24_7

# %% [markdown]
# Построим интерактивную столбчатую диаграмму для визуального представления полученных данных

# %%
# строим график
fig = px.bar(coffee_house_24_7, 
             x='district', 
             y='count',
             color='district',
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение круглосуточных кофеен по округам',
                  title_x=0.45,
                  xaxis_title='Административный район',
                  yaxis_title='Кол-во кофеен',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# Больше всего круглосуточных кофеен опять же в ЦАО, на этот округ приходится 25 кофеен. Сравнивая полученный график с графиком Распределения кофеен по округам, можно заметить, что немного изменилось распределение заведений.После ЦАО, лидерами по кол-ву круглосуточных кофеен стали ЗАО и ЮЗАО. На них приходится 9 и 7 кофеен соответственно.Спрос в этих округах, в том числе в ЦАО мог быть вызван деловой активностью посетителей. В ЮВАО и ЮАО в основном спальные районы, поэтому там всего по 1-ой круглосуточной кофейне.

# %% [markdown]
# ###  Распределение рейтингов кофеен  по административным округам

# %% [markdown]
# Узнаем распределение  рейтингов кофеен по административным округам. Для этого построим график violinplot. Этот график характеризует форму распределения значений.Также с помощью этого графика мы получим информацию по медианному и среднему значению рейтингов кофеен по каждому административному округу.

# %%
#Строим график
fig = px.violin(data_coffee_house, 
                y='rating', 
                x='district', 
                color='district',
                box=True, 
                hover_data=data.columns,
                color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение рейтингов кофеен по административным округам',
                  title_x=0.45,
                  xaxis_title='Административный округ',
                  yaxis_title='Рейтинг',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))


# оформляем график
fig.update_traces(meanline_visible=True)
fig.update_yaxes(zeroline=False)
fig.update_xaxes(tickangle=45)
fig.show()

# %% [markdown]
# По всем округам наблюдаются выбросы с низкими оценками по отдельно взятым кофейням.Особенно много выбросов в СВАО,ЦАО и ЮВАО .Детальная информация доступна при наведении курсора на любой из выбросов.Мы уже выяснили, что В СВАО достаточно немного кофеен, но кол-во заведений с аномально мальньким рейтингом, столько же как в ЦАО и достигает 7.В ЮВАО их 6.
#
# Основные значения рейтинга варьируются от 4 до 4.5.Рассмотрим распределения в крупном масштабе.

# %%
#Строим график
fig = px.violin(data_coffee_house, 
                y='rating', 
                x='district', 
                color='district',
                box=True, 
                hover_data=data.columns,
                color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение рейтингов кофеен по административным округам',
                  title_x=0.45,
                  xaxis_title='Административный округ',
                  yaxis_title='Рейтинг',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))


# оформляем график
fig.update_traces(meanline_visible=True)
fig.update_yaxes(range=[3.8, 5])
fig.update_yaxes(zeroline=False)
fig.update_xaxes(tickangle=45)
fig.show()

# %%
data_coffee_house.pivot_table(index='district',aggfunc={'rating':['mean','median']})

# %% [markdown]
# По полученному графику можно заметить следующее:
# - В ЦАО,СЗАО,САО чаще всего стабильно хорошие кофейни,где медианное значение 4.3, а среднее 4.30 - 4,33.
# - В ЮАО,ЮЗАО,ЮВАО,СВАО,ВАО имеется некоторый дисбаланс среди кофеен. Имеются отдельно взятые заведения с низкими оценками, которые влияют на всю выборку.Медианное значение 4.3, а среднее 4.21 - 4,28
# - В ЗАО заведения с наихудшим медианным рейтингом в 4.2 и среднем в 4.19.Возможно,что обеспеченные люди живущие там, более требовательны к кофейням или действительно в этом округе не хватает кофеен с качественным обслуживанием.

# %% [markdown]
# ### Распределение стоимости чашки капучино в кофейнях

# %% [markdown]
# Узнаем,на какую стоимость чашки капучино стоит ориентироваться при открытии кофейни. Для этого нам необходимо построить несколько графиков распределения стоимости чашки капучино в разрезе административных округов и сетей кофеен.

# %% [markdown]
# Узнаем распределение стоимости чашки капучино в кофейнях по административным округам. Для этого построим график violinplot.

# %% [markdown]
# <a id="распределение_стоимости_чашки_капучино"></a>

# %%
#Строим график
fig = px.violin(data_coffee_house[data_coffee_house['middle_coffee_cup']<1568], 
                y='middle_coffee_cup', 
                x='district', 
                color='district',
                box=True, 
                hover_data=data.columns,
                color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение стоимости чашки капучино в кофейнях по административным округам',
                  title_x=0.45,
                  xaxis_title='Административный округ',
                  yaxis_title='Стоимости чашки капучино',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))


# оформляем график
fig.update_traces(meanline_visible=True)
fig.update_yaxes(zeroline=False)
fig.update_xaxes(tickangle=45)
fig.show()

# %% [markdown]
# Престижные районы с высоким уровнем жизни и богатые обилием институтов стали самыми дорогими по стоимости чашки капучино в кофейнях,так в СЗАО мидиана и среднее составило 165 руб. В ЮЗАО зафиксирована рекордная медианная стоимость в 198 руб и среднее в 184 руб.Очень большой перекос,значит достаточно много недорогих кофеен, искажающих среднее.В ЦАО большая проходимость, медианная стоимость в 190 руб и среднее в 187 руб.В ЗАО тоже высокая стоимость чашки,медианная и средняя стоимость составила 189 руб. На Востоке и Юго-востоке столицы чашка капучино обойдётся в 135-147 руб.

# %%
data_coffee_house[data_coffee_house['middle_coffee_cup']<1568].pivot_table(index='district',
                                                                           values='middle_coffee_cup',
                                                                           aggfunc={'middle_coffee_cup':['median','mean']}).sort_values(by='median',ascending=False)

# %% [markdown]
# Представленная таблица дополняет восприятие графика

# %% [markdown]
# Теперь посмотрим какие сети кофеен представлены в данных и построим таблицу распределения кол-ва заведений по топ-15 сетевым кофейням, посмотрим на их медианное и среднее значение стоимости чашки капучино.

# %%
coffee_house_chain = data_coffee_house.query('chain == 1').groupby('name').agg({'name':'count','middle_coffee_cup':['median','mean']})
coffee_house_chain.columns=['count','median_price','mean_price']
coffee_house_chain = coffee_house_chain.sort_values(by='count',ascending=False).head(15)
coffee_house_chain.reset_index(inplace=True)
coffee_house_chain

# %% [markdown]
# Построим  график распределения

# %%
# строим график
fig = px.bar(coffee_house_chain, 
             x='name', 
             y='count',
             color='name',
             hover_data=['name', 'count','median_price','mean_price'],
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение кол-ва заведений по топ-15 сетевым кофейням',
                  title_x=0.45,
                  xaxis_title='Название сети',
                  yaxis_title='Кол-во кофеен',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# По полученной таблице и графику видно, что крупные сети: `one price coffee`,`кофепорт`,`cofefest` продают чашку капучино в среднем и медианном значении до ~100 руб. Самая крупная сеть `шоколадница` с 118 заведениями продаёт по средней и медианной цене в 256 руб. Шоколадница - это крупный, известный бренд, давно зарекомендовавший себя премиум кофе. На него точно не стоит ориентироваться начинающим, ноунейм компаниям по ценообразованию. Довольно крупная сеть `cofix` c 60-ю точками вообще продают чашку капучино в среднем за ~ 68 РУБ.

# %% [markdown]
# ### Рекомендации для открытия новой кофейни

# %% [markdown]
# 1. Прежде всего кофейню необходимо открывать в высоко проходимом месте. К примеру это могут быть офисные здания,ТЦ, колледжи, ВУЗы,метро, автовокзалы и парки. Заведение должно располагаться в таком месте, где люди непосредственно проводят определённую часть своего времени. Я бы рекомендовал открывать кофейню по дороге в ВУЗ, таким образом мы обеспечим непрерывный утренний, дневной и вечерний приход посетителей в наше заведение. Ведь студенты бывают разных курсов,форм обучения, структуры образования, соответственно приходят и уходят с учёбы они в разное время. Тем более, что основная ЦА кофеен- это студенты и молодежь.
# 2. Данная [карта](https://old.miccedu.ru/map/) говорит нам о том, что большая часть ВУЗов сосредоточена в ЦАО, ЮЗАО, СВАО и САО. Я бы рекомендовал открыть кофейню в САО, СВАО или ЮЗАО. ЦАО перегружен обилием кофеен, более высокая стоимость аренды и студентов снимающих в этом округе жильё - мало.
#    - 1 вариант: В СВАО и САО очень мало круглосуточных кофеен, предлагаю открыть круглосуточную кофейню, таким образом мы могли бы занять нишу, нашими ЦА будут студенты  проживающие в непосредственной близосити от института.Заведение должно иметь небольшую площадь на 10-12 сидячих мест.Ценообразование рыночное по округу среди похожих по формату кофеен.
#    - 2 вариант: В ЮЗАО доля круглосуточных кофеен намного выше среди всех кофеен по округу, а вот самих кофеен гораздо меньше, чем в САО и СВАО. Тем более, что средний чек за чашку капучино в этом округе выше остальных,значит есть возможность конкурировать. Предлагаю открыть кофейню с фикс. графиком. Заведение должно иметь небольшую площадь на 10-12 сидячих мест.Ценообразование на 20% ниже среди похожих по формату кофеен.К примеру при медианной стоимости чашки капучино в 198 руб по рынку, мы установим прайс в 158 РУБ, чтобы привлечь клиентов на этапе развития бизнеса.

# %% [markdown]
# **Вывод**
#
# Мы провели исследование рынка кофеен и нашли некоторые особенности, зависимости.Дали рекомендации для открытия нового заведения
#
# 1. Всего представлено 1410 кофеен в датасете
#
# 2. В ЦАО представлено 427 кофеен, это ~30% от всех кофеен Москвы. в ЗАО 150 кофеен, ЮЗАО 96, а в СЗАО меньше всех, всего 62 кофейни.
#
# 3. В Москве 58 круглосуточных кофеен.Занимаемая рыночная доля круглосуточных кофеен всего 4.11 %. Больше всего круглосуточных кофеен  в ЦАО (25 кофеен) .После ЦАО, лидерами по кол-ву круглосуточных кофеен стали ЗАО и ЮЗАО. На них приходится 9 и 7 кофеен соответственно.Спрос в этих округах, в том числе в ЦАО мог быть вызван деловой активностью посетителей. В ЮВАО и ЮАО в основном спальные районы, поэтому там всего по 1-ой круглосуточной кофейне.
#
# 4. Основные значения рейтинга кофейни варьируются от 4 до 4.5. По всем округам наблюдаются выбросы с низкими оценками по отдельно взятым кофейням.Особенно много выбросов в СВАО,ЦАО и ЮВАО
#    - В ЦАО,СЗАО,САО чаще всего стабильно хорошие кофейни,где медианное значение 4.3, а среднее 4.30 - 4,33.
#    - В ЮАО,ЮЗАО,ЮВАО,СВАО,ВАО имеется некоторый дисбаланс среди кофеен. Имеются отдельно взятые заведения с низкими оценками, которые влияют на всю выборку.Медианное значение 4.3, а среднее 4.21 - 4,28
#    - В ЗАО заведения с наихудшим медианным рейтингом в 4.2 и среднем в 4.19.Возможно,что обеспеченные люди живущие там, более требовательны к кофейням или действительно в этом округе не хватает кофеен с качественным обслуживанием.
#
# 5. Полную картину распределения стоимости чашки капучино в кофейнях по административным округам можно увидеть [здесь](#распределение_стоимости_чашки_капучино) Престижные районы с высоким уровнем жизни и богатые обилием институтов стали самыми дорогими по стоимости чашки капучино в кофейнях.
#    - в СЗАО мидиана и среднее составило 165 руб.
#    - В ЮЗАО зафиксирована рекордная медианная стоимость в 198 руб и среднее в 184 руб.
#    - В ЦАО большая проходимость, медианная стоимость в 190 руб и среднее в 187 руб.
#    - В ЗАО тоже высокая стоимость чашки,медианная и средняя стоимость составила 189 руб.
#    - На Востоке и Юго-востоке столицы чашка капучино обойдётся в 135-147 руб.
#
# 6. Стоимости чашки капучино в разрезе сетевых кофеен следующая:
#    - Крупные сети: one price coffee,кофепорт,cofefest продают чашку капучино в среднем и медианном значении до ~100 руб.
#    - Самая крупная сеть шоколадница с 119 заведениями продаёт по средней и медианной цене в 256 руб
#    - крупная сеть cofix c 60-ю точками продаёт чашку капучино в среднем за ~ 68 РУБ.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В рамках проекта было проведено исследование рынка заведений общественного питания Москвы и предоставлены рекомендации для открытия кофейни
#
# **В процессе обзора и предобработки данных было обнаружено:**
#
# - В представленном для анализа файле - данные о заведениях общественного питания Москвы.Всего представлено 8406 заведений.
# - Пропуски в столбцах hours,price,avg_bill  заменены на значение unknown.
# - Пропуски в столбцах middle_avg_bill,middle_coffee_cup,seats оставлены без изменений
# - Явные дубликаты не выявлены
# - Аномальное значение в столбце middle_avg_bill, где заведение под названием "кофемания" расположенная по адресу москва улица новый арбат 19 имеет средний чек в размере 0 ₽ - устранено.
# - Аномальное значение в столбце middle_avg_bill, где заведение под названием "крошка картошка" расположенное по адресу москва щёлковское шоссе вл75 имеет средний чек в размере 5500 ₽ - устранено.
# - Аномальное значение в столбце middle_coffee_cup, где заведение под названием "шоколадница" расположенное по адресу москва большая семёновская улица 27 корп 1 имеет средний чек за чашку капучино в размере 1568 ₽ - устранено.
#
# - Добавлены:
#   - столбец street с названиями улиц
#   - столбец is_24/7 с обозначением, что заведение работает ежедневно и круглосуточно
# - Неявные дубликаты устранены
#
# **В рамках исследования рынка общепита были обнаружены некоторые зависимости и особенности:**
#
# 1. Общее кол-во заведений в Москве составило 8398 ед.
#
#
# 2.  Лидерами рынка являются заведения в категории кафе,ресторан,кофейня. Доля кафе составляет ~ 28% от всего рынка общепита Москвы, всего заведений этой категории 2376 ед. Занимаемая доля рынка ресторанов ~ 25%. всего заведений 2042 ед. Кофейня занимает 3-е место при 1410 ед. заведений и доли рынка в ~17%.Рыночная доля остальных категорий варьируется от 3 до 9% по Москве. Меньше всего булочных, доля рынка всего ~3%.
#
#
#
# 3. Существует прямая зависимость между кол-ом заведений и кол-ом посадочных мест.Медианна числа посадочных мест на одно заведение варьируется в пределах от 50 до 86 ед. в зависимости от категории заведения.В заведениях категории: ресторан,кофейня,бар и столовая больше всего посадочных мест.Подробное распределение кол-ва посадочных мест [здесь](#Распределение)
#
#
# 4. Доля несетевых заведений по рынку общепита Москвы составляет 61.9%, абсолютное значение 5199 заведений. По сетевым заведениям доля 38.1% ,а кол-во 3199 заведений.
#
# 5. В разрезе сетевых заведений лидерами рынка являются заведения в категории `кафе`,`ресторан`,`кофейня`.
#
#   - Доля сетевых заведений от всех заведений по категории `кафе` составляет ~ 33% .Доля сетевых заведений от общего числа сетевых заведений  составляет ~ 24%. Кол-во сетевых заведений этой категории 779 ед.
#
#
#   - Доля сетевых заведений от всех заведений в категории `ресторан` составляет ~ 36%.Доля сетевых заведений от общего числа сетевых заведений  составляет ~ 23%. Всего заведений 729 ед.
#
#
#   - Доля сетевых заведений от всех в категории `кофейня` составляет ~ 51%.Доля сетевых заведений от общего числа сетевых заведений составляет ~ 22%.Всего заведений 717 ед.
#
#   - Рыночная доля всех остальных сетевых заведений от общего числа сетевых заведений варьируется от 2.75 до 10% по Москве. Меньше всего булочных и столовых.
#
# - Большая часть сетевых заведений приходится на заведения категории кофейня. Лидером является сеть шоколадницас 119 заведениями по Москве.На one price coffee и cofix приходится 71 и 65 заведений соответственно.Всего 5 крупных сетей кофеен.
#
# 6. На рынке ресторанов и кафе выделяются три крупные сети в каждой из этих категорий. `Яндекс.Лавка` с 69 заведениями лидирует среди ресторанов, а в сегменте кафе - `Кулинарная Лавка братьев Караваевых` с 39 заведениями. В сфере пиццерий две популярные сети, `Доминос Пицца` с 76 заведениями и `Додо Пицца` с 74 заведениями. Среди крупных сетей быстрого питания выделяется `Хинкальная` с 44 заведениями, а среди булочных - сеть `Буханка`.
#
# 7. В ЦАО больше всего кол-во заведений (2241 ед.), а в СЗАО меньше всего (409 ед.). Во всех округах, за исключением центрального, категория `кафе` лидирует по количеству заведений. В центральном районе, напротив, `рестораны` занимают первое место.
#
# 8. Основные значения рейтинга варьируются от 3.9 до 4.6
# - Бары,пабы получают чаще остальных высокий рейтинг от посетителей, где медианное значение 4.4, а среднее 4.38.
# - Булочная,кофейня,пиццерия,ресторан и столовая получили медианный рейтинг 4.3, среднее варьируется от 4.21 до 4.30
# -  Заведения быстрого питания  и кафе получили медианный рейтинг 4.2, среднее варьируется от 4.05 до 4.12
#
# 9. Средний рейтинг заведений по округам:
# - В ЦАО 4.38
# - В САО и СЗАО в диапазоне 4.2 - 4.24
# - ЮВАО отличился низким рейтингом заведений,среднее значение 4.1.
# - По остальным районам наблюдается устойчивое значение в диапазоне 4.14 - 4.18
#
# 10. Мы нашли [топ-15](#Распределение_) улиц по кол-ву заведений.На Проспекте мира и Профсоюзной улице оказалось более 100 заведений. На Пятницкой улице и улице Миклухо-Маклая менее 50 заведений общепита. По остальным улицам,проспектам, шоссе численность находится в диапазоне от 50 до 100 заведений. Доли категорий заведений на каждой улице индвидуальны и зависят от территориального расположения отдельно взятой улицы.
#
# 11. Самыми платёжеспособными оказались посетители ЗАО и ЦАО, их средний чек составил 1000 руб.Далее следует СЗАО с средним чеком в 700 руб. По остальным округам средний чек находится в диапазоне 500 - 650 руб. Меньше всего платят посетители ЮВАО
#
#
# **В рамках исследования рынка кофеен были обнаружены некоторые зависимости и особенности:**
#
# 1. Всего представлено 1410 кофеен в датасете
#
# 2. В ЦАО представлено 427 кофеен, это ~30% от всех кофеен Москвы. в ЗАО 150 кофеен, ЮЗАО 96, а в СЗАО меньше всех, всего 62 кофейни.
#
# 3. В Москве 58 круглосуточных кофеен.Занимаемая рыночная доля круглосуточных кофеен всего 4.11 %. Больше всего круглосуточных кофеен  в ЦАО (25 кофеен) .После ЦАО, лидерами по кол-ву круглосуточных кофеен стали ЗАО и ЮЗАО. На них приходится 9 и 7 кофеен соответственно.Спрос в этих округах, в том числе в ЦАО мог быть вызван деловой активностью посетителей. В ЮВАО и ЮАО в основном спальные районы, поэтому там всего по 1-ой круглосуточной кофейне.
#
# 4. Основные значения рейтинга кофейни варьируются от 4 до 4.5. По всем округам наблюдаются выбросы с низкими оценками по отдельно взятым кофейням.Особенно много выбросов в СВАО,ЦАО и ЮВАО
#    - В ЦАО,СЗАО,САО чаще всего стабильно хорошие кофейни,где медианное значение 4.3, а среднее 4.30 - 4,33.
#    - В ЮАО,ЮЗАО,ЮВАО,СВАО,ВАО имеется некоторый дисбаланс среди кофеен. Имеются отдельно взятые заведения с низкими оценками, которые влияют на всю выборку.Медианное значение 4.3, а среднее 4.21 - 4,28
#    - В ЗАО заведения с наихудшим медианным рейтингом в 4.2 и среднем в 4.19.Возможно,что обеспеченные люди живущие там, более требовательны к кофейням или действительно в этом округе не хватает кофеен с качественным обслуживанием.
#
# 5. Полную картину распределения стоимости чашки капучино в кофейнях по административным округам можно увидеть [здесь](#распределение_стоимости_чашки_капучино) Престижные районы с высоким уровнем жизни и богатые обилием институтов стали самыми дорогими по стоимости чашки капучино в кофейнях.
#    - в СЗАО мидиана и среднее составило 165 руб.
#    - В ЮЗАО зафиксирована рекордная медианная стоимость в 198 руб и среднее в 184 руб.
#    - В ЦАО большая проходимость, медианная стоимость в 190 руб и среднее в 187 руб.
#    - В ЗАО тоже высокая стоимость чашки,медианная и средняя стоимость составила 189 руб.
#    - На Востоке и Юго-востоке столицы чашка капучино обойдётся в 135-147 руб.
#
# 6. Стоимости чашки капучино в разрезе сетевых кофеен следующая:
#    - Крупные сети: one price coffee,кофепорт,cofefest продают чашку капучино в среднем и медианном значении до ~100 руб.
#    - Самая крупная сеть шоколадница с 119 заведениями продаёт по средней и медианной цене в 256 руб
#    - крупная сеть cofix c 60-ю точками продаёт чашку капучино в среднем за ~ 68 РУБ.
#
#
# **Рекомендации для открытия новой кофейни**
#
# Прежде всего, успешное открытие кофейни требует стратегического выбора местоположения. Мы должны учесть, что кофейня привлечет клиентов, если будет находиться в месте с высокой проходимостью. Такие места включают в себя офисные здания, торговые центры, колледжи, университеты, метро, автовокзалы и парки. Мы должны ориентироваться на те места, где люди проводят значительное время, и в этом контексте, открытие кофейни на пути к университетам представляется очень перспективным. Это позволит нам обеспечить постоянный поток клиентов в утреннее, дневное и вечернее время, учитывая, что студенты учатся в разное время и имеют разные расписания.
#
# Так как основная целевая аудитория нашей кофейни - студенты и молодежь, мы должны выбрать местоположение в соответствии с этим. Согласно карте, большинство университетов сосредоточены в ЦАО, ЮЗАО, СВАО и САО. Рекомендуется выбрать место в одном из этих округов.
#
# Центральный округ перегружен кофейнями, а аренда здесь высока, и студенты, как правило, не проживают в этом районе. Поэтому мы рассматриваем два варианта:
#
# Северный административный округ (САО) и Северо-восточный административный округ (СВАО): В этих округах отсутствует множество круглосуточных кофеен. Мы можем предложить круглосуточное заведение, которое будет удобно для студентов, живущих неподалеку от института. Размер кофейни должен быть небольшим, на 10-12 посадочных мест, с ценами, соответствующими рыночным стандартам.
#
# Южный административный округ (ЮЗАО): В ЮЗАО доля круглосуточных кофеен выше среди всех округов, и студенты здесь готовы платить выше за чашку капучино. Мы предлагаем открыть кофейню с фиксированным графиком работы, также с небольшим количеством посадочных мест. Ценообразование на 20% ниже среди похожих по формату кофеен, привлекая клиентов ценовым преимуществом в начальном этапе развития бизнеса.
#
# В обоих вариантах местоположения нашей кофейни мы сможем привлечь студентов и молодежь, предоставляя им качественные напитки и уютную атмосферу, соответствующую их потребностям и бюджету. Такой подход обеспечит успешное развитие нашего бизнеса и удовлетворит потребности наших клиентов.

# %% [markdown]
# ## Презентация исследования

# %% [markdown]
# В рамках проекта мы подготовили презентацию проведённого исследования для инвесторов из фонда «Shut Up and Take My Money».Мы нашли интересные особенности и презентовали полученные результаты, которые в будущем помогут в выборе подходящего места для открытия кофейни.

# %% [markdown]
# Презентация:(https://disk.yandex.ru/i/oMDrNJgMszc5pA)
